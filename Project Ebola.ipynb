# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ebola = pd.read_csv(r'C:\Users\USER-PC\Documents\Data Science\data set\ebola_2014_2016_clean.csv')

# %%
ebola.columns
# Out:
# Index(['Country', 'Date',
#        'Cumulative no. of confirmed, probable and suspected cases',
#        'Cumulative no. of confirmed, probable and suspected deaths'],
#       dtype='object')

# %%
ebola.describe()
# Out:
#        Cumulative no. of confirmed, probable and suspected cases  \
# count                                        2477.000000
# mean                                         2553.678644
# std                                          4427.118148
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             8.000000
# 75%                                          3657.000000
# max                                         14122.000000
#
#        Cumulative no. of confirmed, probable and suspected deaths
# count                                        2485.000000
# mean                                         1028.347686
# std                                          1656.064372
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             6.000000
# 75%                                          2386.000000
# max                                          4806.000000

# %%
ebola.head()
# Out:
#         Country        Date  \
# 0        Guinea  2014-08-29
# 1       Nigeria  2014-08-29
# 2  Sierra Leone  2014-08-29
# 3       Liberia  2014-08-29
# 4  Sierra Leone  2014-09-05
#
#    Cumulative no. of confirmed, probable and suspected cases  \
# 0                                              648.0
# 1                                               19.0
# 2                                             1026.0
# 3                                             1378.0
# 4                                             1261.0
#
#    Cumulative no. of confirmed, probable and suspected deaths
# 0                                              430.0
# 1                                                7.0
# 2                                              422.0
# 3                                              694.0
# 4                                              491.0

# %%
e_country = ebola.groupby('Country').sum()

# %%
e_country
# Out:
#                           Cumulative no. of confirmed, probable and suspected cases  \
# Country
# Guinea                                                             854118.0
# Italy                                                                 141.0
# Liberia                                                           2459122.0
# Mali                                                                 1865.0
# Nigeria                                                              5105.0
# Senegal                                                               258.0
# Sierra Leone                                                      3003428.0
# Spain                                                                 243.0
# United Kingdom                                                        215.0
# United States of America                                              967.0
#
#                           Cumulative no. of confirmed, probable and suspected deaths
# Country
# Guinea                                                             563069.0
# Italy                                                                   0.0
# Liberia                                                           1099833.0
# Mali                                                                 1427.0
# Nigeria                                                              2039.0
# Senegal                                                                 0.0
# Sierra Leone                                                       888834.0
# Spain                                                                   0.0
# United Kingdom                                                          0.0
# United States of America                                              242.0

# %%
ebola.head()
# Out:
#         Country        Date  \
# 0        Guinea  2014-08-29
# 1       Nigeria  2014-08-29
# 2  Sierra Leone  2014-08-29
# 3       Liberia  2014-08-29
# 4  Sierra Leone  2014-09-05
#
#    Cumulative no. of confirmed, probable and suspected cases  \
# 0                                              648.0
# 1                                               19.0
# 2                                             1026.0
# 3                                             1378.0
# 4                                             1261.0
#
#    Cumulative no. of confirmed, probable and suspected deaths
# 0                                              430.0
# 1                                                7.0
# 2                                              422.0
# 3                                              694.0
# 4                                              491.0

# %%
sns.scatterplot(x= 'Cumulative no. of confirmed, probable and suspected cases', y='Cumulative no. of confirmed, probable and suspected deaths',
               hue= 'Country', data= ebola)
plt.legend(loc=(1.1,0.2))

# %%
sns.distplot(ebola['Cumulative no. of confirmed, probable and suspected cases'], kde=False)

# %%
sns.distplot(ebola['Cumulative no. of confirmed, probable and suspected deaths'], kde=False)

# %%
sns.jointplot(x= 'Cumulative no. of confirmed, probable and suspected deaths', y= 'Cumulative no. of confirmed, probable and suspected cases',
             data=ebola, kind='reg', color='blue')

# %%
e_country.corr().plot(kind='bar')

# %%
sns.countplot(y= 'Cumulative no. of confirmed, probable and suspected cases', data=e_country)

# %%
e_country.plot()

# %%
e_country.head()
# Out:
#          Cumulative no. of confirmed, probable and suspected cases  \
# Country
# Guinea                                            854118.0
# Italy                                                141.0
# Liberia                                          2459122.0
# Mali                                                1865.0
# Nigeria                                             5105.0
#
#          Cumulative no. of confirmed, probable and suspected deaths
# Country
# Guinea                                            563069.0
# Italy                                                  0.0
# Liberia                                          1099833.0
# Mali                                                1427.0
# Nigeria                                             2039.0

# %%
sns.scatterplot(x= 'Cumulative no. of confirmed, probable and suspected deaths', y= 'Cumulative no. of confirmed, probable and suspected cases', data= e_country)

# %%
sns.lmplot(x= 'Cumulative no. of confirmed, probable and suspected deaths', y= 'Cumulative no. of confirmed, probable and suspected cases',
             data=ebola, hue='Country')

# %%
# observe the trend in countries less than 500 cases
e_country[e_country['Cumulative no. of confirmed, probable and suspected cases'] < 500]['Cumulative no. of confirmed, probable and suspected deaths']
# Out:
# Country
# Italy             0.0
# Senegal           0.0
# Spain             0.0
# United Kingdom    0.0
# Name: Cumulative no. of confirmed, probable and suspected deaths, dtype: float64

# %%
# Evidently, countries with less than 500 cases no single death

# %%
# observe the trend in countries less than 500 cases

usa = e_country[(e_country['Cumulative no. of confirmed, probable and suspected cases'] > 500) & (e_country['Cumulative no. of confirmed, probable and suspected cases'] < 1000)]

# %%
usa
# Out:
#                           Cumulative no. of confirmed, probable and suspected cases  \
# Country
# United States of America                                              967.0
#
#                           Cumulative no. of confirmed, probable and suspected deaths
# Country
# United States of America                                              242.0

# %%
sns.barplot(usa)

# %%
usa.corr( method='kendall')
# Out:
#                                                     Cumulative no. of confirmed, probable and suspected cases  \
# Cumulative no. of confirmed, probable and suspe...                                                1.0
# Cumulative no. of confirmed, probable and suspe...                                                NaN
#
#                                                     Cumulative no. of confirmed, probable and suspected deaths
# Cumulative no. of confirmed, probable and suspe...                                                NaN
# Cumulative no. of confirmed, probable and suspe...                                                1.0

# %%
date = ebola.groupby(by='Date').sum()

# %%
date.head()
# Out:
#             Cumulative no. of confirmed, probable and suspected cases  \
# Date
# 2014-08-29                                             3071.0
# 2014-09-05                                             3967.0
# 2014-09-08                                             4293.0
# 2014-09-12                                             4390.0
# 2014-09-16                                             4985.0
#
#             Cumulative no. of confirmed, probable and suspected deaths
# Date
# 2014-08-29                                             1553.0
# 2014-09-05                                             2105.0
# 2014-09-08                                             2296.0
# 2014-09-12                                             2226.0
# 2014-09-16                                             2461.0

# %%
import chart_studio.plotly as cs
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = dict(type ='choropleth',
           locations = ebola['Country'],
            locationmode='ISO-3',
           colorscale = 'Greens',
           text =ebola['Country'],
            marker = dict(line = dict(color = 'rgb(12, 12, 12)', width = 2)),
           z = ebola['Cumulative no. of confirmed, probable and suspected cases'], 
           colorbar = {'title': 'Affected Countries With Ebola'})

# %%
layout = dict(title = 'Affected Countries With Ebola',
             geo = dict(showframe = True,
                        showlakes = True, lakecolor= 'rgb(85,173,240)',
                       projection = {'type': 'natural earth'}))

# %%
choromap = go.Figure(data = [data], layout = layout)

# %%
iplot(choromap)
# Out:
# <div>
#
#
#             <div id="f0ff4e3f-9386-48f8-805e-623af8010817" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f0ff4e3f-9386-48f8-805e-623af8010817")) {
#                     Plotly.newPlot(
#                         'f0ff4e3f-9386-48f8-805e-623af8010817',
#                         [{"colorbar": {"title": {"text": "Affected Countries With Ebola"}}, "colorscale": [[0.0, "rgb(247,252,245)"], [0.125, "rgb(229,245,224)"], [0.25, "rgb(199,233,192)"], [0.375, "rgb(161,217,155)"], [0.5, "rgb(116,196,118)"], [0.625, "rgb(65,171,93)"], [0.75, "rgb(35,139,69)"], [0.875, "rgb(0,109,44)"], [1.0, "rgb(0,68,27)"]], "locationmode": "ISO-3", "locations": ["Guinea", "Nigeria